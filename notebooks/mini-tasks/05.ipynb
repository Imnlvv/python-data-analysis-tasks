# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 01

# %%
train = pd.read_csv('train1_b.csv')
train.head()
# Out:
#    season   atemp  humidity  windspeed
# 0       1  14.395        81        0.0
# 1       1  13.635        80        0.0
# 2       1  13.635        80        0.0
# 3       1  14.395        75        0.0
# 4       1  14.395        75        0.0

# %%
train['atemp'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['humidity'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
train['windspeed'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 02

# %%
train2 = pd.read_csv('train1_C.csv')
train2.head()
# Out:
#        Car Name  Year    Region  FuelType  Mileage  Price  Owners
# 0  Ford Transit  2002     Goris    Diesel   215000  12000       4
# 1    Ford Focus  2017    Ijevan  Gasoline    72000  11500       5
# 2   Opel Vectra  1998   Armavir  Gasoline   466000   4000       5
# 3       Mazda 6  2020  Nor Nork  Gasoline   100000  22000       3
# 4   Opel Vectra  1998   Armavir  Gasoline   318000   3500       6

# %%
train2[((train2['FuelType'] == 'Gasoline') & (train2['Region'] == 'Armavir'))].sort_values('Year')
# Out:
#                    Car Name  Year   Region  FuelType  Mileage  Price  Owners
# 7210     Mercedes-Benz W124  1991  Armavir  Gasoline   269000   4000       1
# 6841      Fiat Tempra wagon  1993  Armavir  Gasoline   150000  47000       5
# 4305            Opel Vectra  1993  Armavir  Gasoline   600000   4700       4
# 1576            Opel Vectra  1994  Armavir  Gasoline   179000  12500       3
# 4241  Mercedes-Benz C-Class  1995  Armavir  Gasoline   300000  14300       4
# ...                     ...   ...      ...       ...      ...    ...     ...
# 1390   Mitsubishi Outlander  2021  Armavir  Gasoline    20000   1500       6
# 3015             Mazda CX-5  2021  Armavir  Gasoline    35000  19700       4
# 2444             Mazda CX-5  2022  Armavir  Gasoline     2177  22500       4
# 5147          Jeep Wrangler  2022  Armavir  Gasoline    20000  16900       6
# 2466      Toyota Highlander  2023  Armavir  Gasoline     1200  16400       1
#
# [221 rows x 7 columns]

# %%
train2[(train2['Year'] >= 2001)]['Mileage'].mean()
# Out:
# np.float64(126058.44031077245)

# %%
round(126058.44031077245, 2)
# Out:
# 126058.44

# %%
def fun(x):
    if 'Toyota' in x:
        return 1
    else:
        return 0

# %%
train2['coded'] = train2['Car Name'].apply(fun)

# %%
train2['coded'].sum()
# Out:
# np.int64(670)

# %% [markdown]
# 03

# %%
train3 = pd.read_csv('train2_C.csv')
train3.head()
# Out:
#       price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0  221900.0         3         1180      5650           0      7      1955
# 1  538000.0         3         2570      7242           0      7      1951
# 2  180000.0         2          770     10000           0      6      1933
# 3  604000.0         4         1960      5000           0      7      1965
# 4  510000.0         3         1680      8080           0      8      1987
#
#    yr_renovated
# 0             0
# 1          1991
# 2             0
# 3             0
# 4             0

# %%
train3[(train3['bedrooms'] == 1)].sort_values('sqft_lot')
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 21552  516500.0         1         1100       638           0      9      2014
# 21519  420000.0         1         1070       675           0      8      2007
# 4446   344000.0         1          760       779           0      8      2006
# 3987   202000.0         1          590       833           0      7      1926
# 19885  310000.0         1         1120       912           0      7      2011
# ...         ...       ...          ...       ...         ...    ...       ...
# 9131   250000.0         1          720    123710           0      6      1935
# 15168  316000.0         1         1780    188465           0     10      2001
# 1653   415000.0         1         3000    204732           0      8      1979
# 3042   362000.0         1          890    211576           0      7      1996
# 17576  375000.0         1          800    533610           0      5      1950
#
#        yr_renovated
# 21552             0
# 21519             0
# 4446              0
# 3987              0
# 19885             0
# ...             ...
# 9131              0
# 15168             0
# 1653              0
# 3042              0
# 17576             0
#
# [199 rows x 8 columns]

# %%
mean_sqft_lot = train3['sqft_lot'].mean()
train3[(train3['waterfront'] == 1) & (train3['sqft_lot'] > mean_sqft_lot)]['grade'].var()
# Out:
# np.float64(3.1409460105112266)

# %%
round(3.1409460105112266, 2)
# Out:
# 3.14

# %%
train3.head()
# Out:
#       price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0  221900.0         3         1180      5650           0      7      1955
# 1  538000.0         3         2570      7242           0      7      1951
# 2  180000.0         2          770     10000           0      6      1933
# 3  604000.0         4         1960      5000           0      7      1965
# 4  510000.0         3         1680      8080           0      8      1987
#
#    yr_renovated
# 0             0
# 1          1991
# 2             0
# 3             0
# 4             0

# %%
train3[(train3['bedrooms'] == 1)].sort_values('sqft_lot')
# Out:
#           price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 21552  516500.0         1         1100       638           0      9      2014
# 21519  420000.0         1         1070       675           0      8      2007
# 4446   344000.0         1          760       779           0      8      2006
# 3987   202000.0         1          590       833           0      7      1926
# 19885  310000.0         1         1120       912           0      7      2011
# ...         ...       ...          ...       ...         ...    ...       ...
# 9131   250000.0         1          720    123710           0      6      1935
# 15168  316000.0         1         1780    188465           0     10      2001
# 1653   415000.0         1         3000    204732           0      8      1979
# 3042   362000.0         1          890    211576           0      7      1996
# 17576  375000.0         1          800    533610           0      5      1950
#
#        yr_renovated
# 21552             0
# 21519             0
# 4446              0
# 3987              0
# 19885             0
# ...             ...
# 9131              0
# 15168             0
# 1653              0
# 3042              0
# 17576             0
#
# [199 rows x 8 columns]

# %%
train3['coded'] = train3['yr_renovated'].apply(fun)

# %%
def fun(x):
    if x == 0:
        return 1
    elif x > 2001:
        return 21
    else:
        return 20

# %%
train3['yr_renovated'].sort_values()
# Out:
# 0           0
# 14285       0
# 14284       0
# 14283       0
# 14282       0
#          ...
# 14859    2015
# 5683     2015
# 11633    2015
# 13216    2015
# 18575    2015
# Name: yr_renovated, Length: 21613, dtype: int64

# %%
train3['coded'].std()
# Out:
# np.float64(3.9140998408066743)

# %%
round(3.9140998408066743, 2)
# Out:
# 3.91

# %%
train3.head()
# Out:
#       price  bedrooms  sqft_living  sqft_lot  waterfront  grade  yr_built  \
# 0  221900.0         3         1180      5650           0      7      1955
# 1  538000.0         3         2570      7242           0      7      1951
# 2  180000.0         2          770     10000           0      6      1933
# 3  604000.0         4         1960      5000           0      7      1965
# 4  510000.0         3         1680      8080           0      8      1987
#
#    yr_renovated  coded
# 0             0      1
# 1          1991     20
# 2             0      1
# 3             0      1
# 4             0      1

# %%
mean_sqft = train3['sqft_lot'].mean()

train3[((train3['waterfront'] == 1) & (train3['sqft_lot'] > mean_sqft))]['grade'].var()
# Out:
# np.float64(3.1409460105112266)

# %%
round(3.133695652173913, 2)
# Out:
# 3.13
