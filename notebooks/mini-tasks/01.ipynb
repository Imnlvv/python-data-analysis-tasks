# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 01

# %%
data = pd.read_csv("datademo2.csv")
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %%
data[(data['Year_of_Release'] < 2005) & (data['Genre'] == 'Sports')].shape
# Out:
# (923, 16)

# %%
data[data['Publisher'] == 'Nintendo'].shape
# Out:
# (706, 16)

# %%
round(16719 / 706, 2)
# Out:
# 23.68

# %% [markdown]
# 02

# %%
taylor = pd.read_csv("Taylor_final.csv")
taylor.head()
# Out:
#                                      name                    album  \
# 0                           Lavender Haze  Midnights (3am Edition)
# 1                                  Maroon  Midnights (3am Edition)
# 2                                     NaN                      NaN
# 3  Snow On The Beach (feat. Lana Del Rey)  Midnights (3am Edition)
# 4                 You're On Your Own, Kid  Midnights (3am Edition)
#
#   release_date  track_number                      id  \
# 0          NaN           1.0  4g2c7NoTWAOSYDy44l9nub
# 1   10/22/2022           2.0  199E1RRrVmVTQqBXih5qRC
# 2   10/22/2022           NaN  02Zkkf2zMkwRGQjZ7T4p8f
# 3   10/22/2022           4.0  6ADDIJxxqzM9LMpm78yzQG
# 4   10/22/2022           NaN  7gVWKBcfIW93YxNBi3ApIE
#
#                                     uri  acousticness  danceability  energy  \
# 0  spotify:track:4g2c7NoTWAOSYDy44l9nub        0.2040         0.735   0.444
# 1  spotify:track:199E1RRrVmVTQqBXih5qRC        0.0593         0.658     NaN
# 2                                   NaN           NaN         0.638   0.634
# 3  spotify:track:6ADDIJxxqzM9LMpm78yzQG        0.7350         0.659   0.323
# 4  spotify:track:7gVWKBcfIW93YxNBi3ApIE        0.4160         0.694   0.380
#
#    instrumentalness  liveness  loudness  speechiness    tempo  valence  \
# 0          0.001200    0.1700   -10.519       0.0684   97.038   0.0984
# 1          0.000000    0.0976    -8.300       0.0379  108.034   0.0382
# 2          0.000001    0.1520    -6.582       0.0457   96.953   0.5190
# 3          0.003210    0.1160   -13.425          NaN  110.007   0.1540
# 4               NaN       NaN   -10.307       0.0614  120.044   0.3760
#
#    popularity  duration_ms
# 0        87.0     202395.0
# 1        87.0     218270.0
# 2        88.0     200690.0
# 3        86.0     256124.0
# 4        87.0     194206.0

# %%
taylor[(taylor['album'] == 'Fearless') & (taylor['energy'] > 0.6)].shape
# Out:
# (36, 17)

# %%
taylor[taylor['album'] == 'Speak Now'].shape
# Out:
# (26, 17)

# %%
round(26 / 1265, 2)
# Out:
# 0.02
